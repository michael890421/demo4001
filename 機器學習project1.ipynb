# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 列出資料

# %%
data = pd.read_csv("crypto prices.csv")
data
# Out:
#       Unnamed: 0        Date  Adj Close (BNB)  Volume (BNB)  Adj Close (BTC)  \
# 0              0   11/9/2017         1.990770      19192200      7143.580078
# 1              1  11/10/2017         1.796840      11155000      6618.140137
# 2              2  11/11/2017         1.670470       8178150      6357.600098
# 3              3  11/12/2017         1.519690      15298700      5950.069824
# 4              4  11/13/2017         1.686620      12238800      6559.490234
# ...          ...         ...              ...           ...              ...
# 1725        1725   7/31/2022       283.579468    1313531523     23336.896484
# 1726        1726    8/1/2022       283.539490    1314157614     23314.199219
# 1727        1727    8/2/2022       283.820984    1768344106     22978.117188
# 1728        1728    8/3/2022       298.356781    2133584480     22846.507813
# 1729        1729    8/4/2022       310.706055    1926587001     22858.423828
#
#       Volume (BTC)  Adj Close (USDT)  Volume (USDT)  Adj Close (ETH)  \
# 0       3226249984          1.008180      358188000       320.884003
# 1       5208249856          1.006010      756446016       299.252991
# 2       4908680192          1.008990      746227968       314.681000
# 3       8957349888          1.012470     1466060032       307.907990
# 4       6263249920          1.009350      767884032       316.716003
# ...            ...               ...            ...              ...
# 1725   23553591896          1.000328    52267348020      1681.517334
# 1726   25849159141          1.000204    50882756969      1635.195801
# 1727   28389250717          1.000159    54793315279      1632.945435
# 1728   26288169966          1.000204    47717439471      1618.874512
# 1729   24817580032          1.000133    44526180493      1608.205811
#
#       Volume (ETH)
# 0        893249984
# 1        885985984
# 2        842300992
# 3       1613479936
# 4       1041889984
# ...            ...
# 1725   14200735370
# 1726   16191371176
# 1727   20426082309
# 1728   16786218830
# 1729   14467440626
#
# [1730 rows x 10 columns]

# %%
data.head()
# Out:
#    Unnamed: 0        Date  Adj Close (BNB)  Volume (BNB)  Adj Close (BTC)  \
# 0           0   11/9/2017          1.99077      19192200      7143.580078
# 1           1  11/10/2017          1.79684      11155000      6618.140137
# 2           2  11/11/2017          1.67047       8178150      6357.600098
# 3           3  11/12/2017          1.51969      15298700      5950.069824
# 4           4  11/13/2017          1.68662      12238800      6559.490234
#
#    Volume (BTC)  Adj Close (USDT)  Volume (USDT)  Adj Close (ETH)  \
# 0    3226249984           1.00818      358188000       320.884003
# 1    5208249856           1.00601      756446016       299.252991
# 2    4908680192           1.00899      746227968       314.681000
# 3    8957349888           1.01247     1466060032       307.907990
# 4    6263249920           1.00935      767884032       316.716003
#
#    Volume (ETH)
# 0     893249984
# 1     885985984
# 2     842300992
# 3    1613479936
# 4    1041889984

# %%
plt.figure(figsize = (20,10))
sns.lineplot(data = data['Adj Close (BNB)'],label = 'BNB')
sns.lineplot(data = data['Adj Close (BTC)'],label = 'BTC')
sns.lineplot(data = data['Adj Close (ETH)'],label = 'ETH')
sns.lineplot(data = data['Adj Close (USDT)'],label = 'USDT')
plt.title('Adjacent Close Price')
# Out:
# Text(0.5, 1.0, 'Adjacent Close Price')

# %%
plt.figure(figsize = (20,10))
sns.lineplot(data = data['Volume (BNB)'],label = 'BNB')
sns.lineplot(data = data['Volume (BTC)'],label = 'BTC')
sns.lineplot(data = data['Volume (ETH)'],label = 'ETH')
sns.lineplot(data = data['Volume (USDT)'],label = 'USDT')
plt.title('Volume')
# Out:
# Text(0.5, 1.0, 'Volume')

# %%
data.corr()
# Out:
#                   Unnamed: 0  Adj Close (BNB)  Volume (BNB)  Adj Close (BTC)  \
# Unnamed: 0          1.000000         0.761237      0.571730         0.743903
# Adj Close (BNB)     0.761237         1.000000      0.732715         0.918562
# Volume (BNB)        0.571730         0.732715      1.000000         0.768149
# Adj Close (BTC)     0.743903         0.918562      0.768149         1.000000
# Volume (BTC)        0.586429         0.407226      0.600409         0.573059
# Adj Close (USDT)   -0.181445        -0.154652     -0.117310        -0.151540
# Volume (USDT)       0.722177         0.659554      0.773426         0.773313
# Adj Close (ETH)     0.697317         0.962406      0.654506         0.926972
# Volume (ETH)        0.674547         0.569978      0.699198         0.672594
#
#                   Volume (BTC)  Adj Close (USDT)  Volume (USDT)  \
# Unnamed: 0            0.586429         -0.181445       0.722177
# Adj Close (BNB)       0.407226         -0.154652       0.659554
# Volume (BNB)          0.600409         -0.117310       0.773426
# Adj Close (BTC)       0.573059         -0.151540       0.773313
# Volume (BTC)          1.000000         -0.095888       0.867511
# Adj Close (USDT)     -0.095888          1.000000      -0.139902
# Volume (USDT)         0.867511         -0.139902       1.000000
# Adj Close (ETH)       0.383787         -0.149685       0.629372
# Volume (ETH)          0.859965         -0.119487       0.948139
#
#                   Adj Close (ETH)  Volume (ETH)
# Unnamed: 0               0.697317      0.674547
# Adj Close (BNB)          0.962406      0.569978
# Volume (BNB)             0.654506      0.699198
# Adj Close (BTC)          0.926972      0.672594
# Volume (BTC)             0.383787      0.859965
# Adj Close (USDT)        -0.149685     -0.119487
# Volume (USDT)            0.629372      0.948139
# Adj Close (ETH)          1.000000      0.545473
# Volume (ETH)             0.545473      1.000000
